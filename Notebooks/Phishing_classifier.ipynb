# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Phishing_Legitimate_full.csv")
df.head()
# Out:
#    id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0   1        3               1          5         72        0
# 1   2        3               1          3        144        0
# 2   3        3               1          2         58        0
# 3   4        3               1          6         79        1
# 4   5        3               0          4         46        0
#
#    NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 0                  0         0            0              0  ...
# 1                  0         0            0              2  ...
# 2                  0         0            0              0  ...
# 3                  0         0            0              0  ...
# 4                  0         0            0              0  ...
#
#    IframeOrFrame  MissingTitle  ImagesOnlyInForm  SubdomainLevelRT  \
# 0              0             0                 1                 1
# 1              0             0                 0                 1
# 2              0             0                 0                 1
# 3              0             0                 0                 1
# 4              1             0                 0                 1
#
#    UrlLengthRT  PctExtResourceUrlsRT  AbnormalExtFormActionR  \
# 0            0                     1                       1
# 1           -1                     1                       1
# 2            0                    -1                       1
# 3           -1                     1                       1
# 4            1                    -1                       0
#
#    ExtMetaScriptLinkRT  PctExtNullSelfRedirectHyperlinksRT  CLASS_LABEL
# 0                   -1                                   1            1
# 1                    1                                   1            1
# 2                   -1                                   0            1
# 3                    1                                  -1            1
# 4                   -1                                  -1            1
#
# [5 rows x 50 columns]

# %%
df.shape
# Out:
# (10000, 50)

# %%
df.tail()
# Out:
#          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 9995   9996        3               1          1         50        0
# 9996   9997        2               1          4         59        1
# 9997   9998        2               1          4         57        0
# 9998   9999        3               1          1         49        0
# 9999  10000        3               1          2         52        3
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# 9995                  0         0            0              0  ...
# 9996                  0         0            0              0  ...
# 9997                  0         0            0              0  ...
# 9998                  0         0            0              0  ...
# 9999                  0         0            0              0  ...
#
#       IframeOrFrame  MissingTitle  ImagesOnlyInForm  SubdomainLevelRT  \
# 9995              0             0                 0                 1
# 9996              1             0                 0                 1
# 9997              0             0                 0                 1
# 9998              1             0                 0                 1
# 9999              0             0                 0                 1
#
#       UrlLengthRT  PctExtResourceUrlsRT  AbnormalExtFormActionR  \
# 9995            1                    -1                       1
# 9996            0                     0                       1
# 9997            0                     1                       1
# 9998            1                     0                       1
# 9999            1                     1                       1
#
#       ExtMetaScriptLinkRT  PctExtNullSelfRedirectHyperlinksRT  CLASS_LABEL
# 9995                    0                                   1            0
# 9996                    0                                   1            0
# 9997                    0                                   1            0
# 9998                    0                                   1            0
# 9999                    1                                   1            0
#
# [5 rows x 50 columns]

# %%
df.drop('id', axis =1, inplace=True)

# %%
# !pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.3.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\shubham kumar\anaconda3\lib\site-packages (from sweetviz) (2.2.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\shubham kumar\anaconda3\lib\site-packages (from sweetviz) (1.26.4)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\shubham kumar\anaconda3\lib\site-packages (from sweetviz) (3.8.4)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\shubham kumar\anaconda3\lib\site-packages (from sweetviz) (4.66.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\shubham kumar\anaconda3\lib\site-packages (from sweetviz) (1.13.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\shubham kumar\anaconda3\lib\site-packages (from sweetviz) (3.1.4)
# Collecting importlib-resources>=1.2.0 (from sweetviz)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shubham kumar\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shubham kumar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\shubham kumar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shubham kumar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shubham kumar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shubham kumar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\shubham kumar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shubham kumar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shubham kumar\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shubham kumar\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shubham kumar\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.3)
# Requirement already satisfied: colorama in c:\users\shubham kumar\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\shubham kumar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Downloading sweetviz-2.3.1-py3-none-any.whl (15.1 MB)
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/15.1 MB 6.3 MB/s eta 0:00:03
#    --- ------------------------------------ 1.3/15.1 MB 3.4 MB/s eta 0:00:05
#    ------ --------------------------------- 2.4/15.1 MB 3.8 MB/s eta 0:00:04
#    ------- -------------------------------- 2.9/15.1 MB 3.8 MB/s eta 0:00:04
#    --------- ------------------------------ 3.4/15.1 MB 3.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.9/15.1 MB 3.5 MB/s eta 0:00:04
#    ----------- ---------------------------- 4.5/15.1 MB 3.1 MB/s eta 0:00:04
#    ------------- -------------------------- 5.2/15.1 MB 3.2 MB/s eta 0:00:04
#    --------------- ------------------------ 6.0/15.1 MB 3.3 MB/s eta 0:00:03
#    ------------------ --------------------- 6.8/15.1 MB 3.4 MB/s eta 0:00:03
#    -------------------- ------------------- 7.6/15.1 MB 3.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 8.7/15.1 MB 3.5 MB/s eta 0:00:02
#    ------------------------ --------------- 9.4/15.1 MB 3.5 MB/s eta 0:00:02
#    --------------------------- ------------ 10.2/15.1 MB 3.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 11.0/15.1 MB 3.5 MB/s eta 0:00:02
#    ------------------------------- -------- 11.8/15.1 MB 3.6 MB/s eta 0:00:01
#    --------------------------------- ------ 12.6/15.1 MB 3.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.4/15.1 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 14.2/15.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.1 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 15.1/15.1 MB 3.6 MB/s eta 0:00:00
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-6.4.0 sweetviz-2.3.1
# DEPRECATION: Loading egg at c:\users\shubham kumar\anaconda3\lib\site-packages\diamond_prediction-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import sweetviz as sv

sweet_report = sv.analyze(df)
sweet_report.show_html('sweet_report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report sweet_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   NumDots                             10000 non-null  int64
#  1   SubdomainLevel                      10000 non-null  int64
#  2   PathLevel                           10000 non-null  int64
#  3   UrlLength                           10000 non-null  int64
#  4   NumDash                             10000 non-null  int64
#  5   NumDashInHostname                   10000 non-null  int64
#  6   AtSymbol                            10000 non-null  int64
#  7   TildeSymbol                         10000 non-null  int64
#  8   NumUnderscore                       10000 non-null  int64
#  9   NumPercent                          10000 non-null  int64
#  10  NumQueryComponents                  10000 non-null  int64
#  11  NumAmpersand                        10000 non-null  int64
#  12  NumHash                             10000 non-null  int64
#  13  NumNumericChars                     10000 non-null  int64
#  14  NoHttps                             10000 non-null  int64
#  15  RandomString                        10000 non-null  int64
#  16  IpAddress                           10000 non-null  int64
#  17  DomainInSubdomains                  10000 non-null  int64
#  18  DomainInPaths                       10000 non-null  int64
#  19  HttpsInHostname                     10000 non-null  int64
#  20  HostnameLength                      10000 non-null  int64
#  21  PathLength                          10000 non-null  int64
#  22  QueryLength                         10000 non-null  int64
#  23  DoubleSlashInPath                   10000 non-null  int64
#  24  NumSensitiveWords                   10000 non-null  int64
#  25  EmbeddedBrandName                   10000 non-null  int64
#  26  PctExtHyperlinks                    10000 non-null  float64
#  27  PctExtResourceUrls                  10000 non-null  float64
#  28  ExtFavicon                          10000 non-null  int64
#  29  InsecureForms                       10000 non-null  int64
#  30  RelativeFormAction                  10000 non-null  int64
#  31  ExtFormAction                       10000 non-null  int64
#  32  AbnormalFormAction                  10000 non-null  int64
#  33  PctNullSelfRedirectHyperlinks       10000 non-null  float64
#  34  FrequentDomainNameMismatch          10000 non-null  int64
#  35  FakeLinkInStatusBar                 10000 non-null  int64
#  36  RightClickDisabled                  10000 non-null  int64
#  37  PopUpWindow                         10000 non-null  int64
#  38  SubmitInfoToEmail                   10000 non-null  int64
#  39  IframeOrFrame                       10000 non-null  int64
#  40  MissingTitle                        10000 non-null  int64
#  41  ImagesOnlyInForm                    10000 non-null  int64
#  42  SubdomainLevelRT                    10000 non-null  int64
#  43  UrlLengthRT                         10000 non-null  int64
#  44  PctExtResourceUrlsRT                10000 non-null  int64
#  45  AbnormalExtFormActionR              10000 non-null  int64
#  46  ExtMetaScriptLinkRT                 10000 non-null  int64
#  47  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  48  CLASS_LABEL                         10000 non-null  int64
# dtypes: float64(3), int64(46)
# memory usage: 3.7 MB

# %%
float_cols = df.select_dtypes('float64')
for i in float_cols:
    df[i] = df[i].astype('float32')
float_cols = df.select_dtypes('int64')
for i in float_cols:
    df[i] = df[i].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   NumDots                             10000 non-null  int32
#  1   SubdomainLevel                      10000 non-null  int32
#  2   PathLevel                           10000 non-null  int32
#  3   UrlLength                           10000 non-null  int32
#  4   NumDash                             10000 non-null  int32
#  5   NumDashInHostname                   10000 non-null  int32
#  6   AtSymbol                            10000 non-null  int32
#  7   TildeSymbol                         10000 non-null  int32
#  8   NumUnderscore                       10000 non-null  int32
#  9   NumPercent                          10000 non-null  int32
#  10  NumQueryComponents                  10000 non-null  int32
#  11  NumAmpersand                        10000 non-null  int32
#  12  NumHash                             10000 non-null  int32
#  13  NumNumericChars                     10000 non-null  int32
#  14  NoHttps                             10000 non-null  int32
#  15  RandomString                        10000 non-null  int32
#  16  IpAddress                           10000 non-null  int32
#  17  DomainInSubdomains                  10000 non-null  int32
#  18  DomainInPaths                       10000 non-null  int32
#  19  HttpsInHostname                     10000 non-null  int32
#  20  HostnameLength                      10000 non-null  int32
#  21  PathLength                          10000 non-null  int32
#  22  QueryLength                         10000 non-null  int32
#  23  DoubleSlashInPath                   10000 non-null  int32
#  24  NumSensitiveWords                   10000 non-null  int32
#  25  EmbeddedBrandName                   10000 non-null  int32
#  26  PctExtHyperlinks                    10000 non-null  float32
#  27  PctExtResourceUrls                  10000 non-null  float32
#  28  ExtFavicon                          10000 non-null  int32
#  29  InsecureForms                       10000 non-null  int32
#  30  RelativeFormAction                  10000 non-null  int32
#  31  ExtFormAction                       10000 non-null  int32
#  32  AbnormalFormAction                  10000 non-null  int32
#  33  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  34  FrequentDomainNameMismatch          10000 non-null  int32
#  35  FakeLinkInStatusBar                 10000 non-null  int32
#  36  RightClickDisabled                  10000 non-null  int32
#  37  PopUpWindow                         10000 non-null  int32
#  38  SubmitInfoToEmail                   10000 non-null  int32
#  39  IframeOrFrame                       10000 non-null  int32
#  40  MissingTitle                        10000 non-null  int32
#  41  ImagesOnlyInForm                    10000 non-null  int32
#  42  SubdomainLevelRT                    10000 non-null  int32
#  43  UrlLengthRT                         10000 non-null  int32
#  44  PctExtResourceUrlsRT                10000 non-null  int32
#  45  AbnormalExtFormActionR              10000 non-null  int32
#  46  ExtMetaScriptLinkRT                 10000 non-null  int32
#  47  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int32
#  48  CLASS_LABEL                         10000 non-null  int32
# dtypes: float32(3), int32(46)
# memory usage: 1.9 MB

# %%
df.rename(columns= {'CLASS_LABEL':'labels'}, inplace = True)

# %%
df.sample(10)
# Out:
#       NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 6393        2               0          2         87        4
# 3896        4               0          5        178        0
# 6911        1               0          5         80        6
# 4843        3               1          3         47        1
# 7973        3               1          1         75        0
# 7754        2               1          5         91        7
# 2777        2               0          5         52        1
# 9363        2               1          1         39        0
# 4387        2               0          2         38        0
# 4099        2               0          6         65        0
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  NumPercent  \
# 6393                  0         0            0              0           0
# 3896                  0         0            0              0           0
# 6911                  0         0            0              0           0
# 4843                  0         0            0              0           0
# 7973                  0         0            0              1           0
# 7754                  0         0            0              0           0
# 2777                  1         0            0              0           0
# 9363                  0         0            0              0           0
# 4387                  0         0            0              0           0
# 4099                  0         0            0              0           0
#
#       ...  IframeOrFrame  MissingTitle  ImagesOnlyInForm  SubdomainLevelRT  \
# 6393  ...              0             0                 0                 1
# 3896  ...              1             0                 0                 1
# 6911  ...              0             0                 0                 1
# 4843  ...              0             0                 0                 1
# 7973  ...              0             0                 0                 1
# 7754  ...              0             0                 0                 1
# 2777  ...              1             0                 0                 1
# 9363  ...              0             0                 0                 1
# 4387  ...              0             0                 0                 1
# 4099  ...              0             0                 0                 1
#
#       UrlLengthRT  PctExtResourceUrlsRT  AbnormalExtFormActionR  \
# 6393           -1                     1                       1
# 3896           -1                     1                       1
# 6911           -1                     0                       1
# 4843            1                     1                       1
# 7973            0                     0                       1
# 7754           -1                     1                       1
# 2777            1                     1                       1
# 9363            1                    -1                       1
# 4387            1                     1                       1
# 4099            0                     1                       1
#
#       ExtMetaScriptLinkRT  PctExtNullSelfRedirectHyperlinksRT  labels
# 6393                    0                                   1       0
# 3896                    0                                   1       1
# 6911                    0                                   0       0
# 4843                   -1                                  -1       1
# 7973                    0                                   1       0
# 7754                    1                                   1       0
# 2777                    0                                   1       1
# 9363                   -1                                   1       0
# 4387                   -1                                  -1       1
# 4099                   -1                                   1       1
#
# [10 rows x 49 columns]

# %%
df.describe()
# Out:
#             NumDots  SubdomainLevel     PathLevel     UrlLength       NumDash  \
# count  10000.000000    10000.000000  10000.000000  10000.000000  10000.000000
# mean       2.445100        0.586800      3.300300     70.264100      1.818000
# std        1.346836        0.751214      1.863241     33.369877      3.106258
# min        1.000000        0.000000      0.000000     12.000000      0.000000
# 25%        2.000000        0.000000      2.000000     48.000000      0.000000
# 50%        2.000000        1.000000      3.000000     62.000000      0.000000
# 75%        3.000000        1.000000      4.000000     84.000000      2.000000
# max       21.000000       14.000000     18.000000    253.000000     55.000000
#
#        NumDashInHostname      AtSymbol   TildeSymbol  NumUnderscore  \
# count       10000.000000  10000.000000  10000.000000    10000.00000
# mean            0.138900      0.000300      0.013100        0.32320
# std             0.545744      0.017319      0.113709        1.11466
# min             0.000000      0.000000      0.000000        0.00000
# 25%             0.000000      0.000000      0.000000        0.00000
# 50%             0.000000      0.000000      0.000000        0.00000
# 75%             0.000000      0.000000      0.000000        0.00000
# max             9.000000      1.000000      1.000000       18.00000
#
#          NumPercent  ...  IframeOrFrame  MissingTitle  ImagesOnlyInForm  \
# count  10000.000000  ...   10000.000000   10000.00000      10000.000000
# mean       0.073800  ...       0.339600       0.03220          0.030400
# std        0.622248  ...       0.473597       0.17654          0.171694
# min        0.000000  ...       0.000000       0.00000          0.000000
# 25%        0.000000  ...       0.000000       0.00000          0.000000
# 50%        0.000000  ...       0.000000       0.00000          0.000000
# 75%        0.000000  ...       1.000000       0.00000          0.000000
# max       19.000000  ...       1.000000       1.00000          1.000000
#
#        SubdomainLevelRT   UrlLengthRT  PctExtResourceUrlsRT  \
# count      10000.000000  10000.000000          10000.000000
# mean           0.956600      0.020200              0.353300
# std            0.248037      0.820036              0.888908
# min           -1.000000     -1.000000             -1.000000
# 25%            1.000000     -1.000000             -1.000000
# 50%            1.000000      0.000000              1.000000
# 75%            1.000000      1.000000              1.000000
# max            1.000000      1.000000              1.000000
#
#        AbnormalExtFormActionR  ExtMetaScriptLinkRT  \
# count            10000.000000         10000.000000
# mean                 0.793200             0.173400
# std                  0.521019             0.755771
# min                 -1.000000            -1.000000
# 25%                  1.000000             0.000000
# 50%                  1.000000             0.000000
# 75%                  1.000000             1.000000
# max                  1.000000             1.000000
#
#        PctExtNullSelfRedirectHyperlinksRT        labels
# count                        10000.000000  10000.000000
# mean                             0.314100      0.500000
# std                              0.897843      0.500025
# min                             -1.000000      0.000000
# 25%                             -1.000000      0.000000
# 50%                              1.000000      0.500000
# 75%                              1.000000      1.000000
# max                              1.000000      1.000000
#
# [8 rows x 49 columns]

# %%
df['labels'].value_counts().plot(kind = 'bar')
plt.show()

# %%
def corr_heatmap(data, idx_s, idx_e):
    y = data['labels']
    temp = data.iloc[:, idx_s:idx_e]
    if 'id' in temp.columns:
        del temp['id']
    temp['labels'] = y
    sns.heatmap(temp.corr(), annot= True, fmt='.2f')
    plt.show()

# %%
pd.set_option('display.max_columns', None)
plt.rcParams['figure.figsize'] = (15,10)
corr_heatmap(df, 0,10)

# %%
corr_heatmap(df,10,20)

# %%
corr_heatmap(df,20,30)

# %%
corr_heatmap(df,30,40)

# %%
corr_heatmap(df,40,50)

# %%
from sklearn.feature_selection import mutual_info_classif

X = df.drop('labels', axis=1)
y = df['labels']

discrete_features = X.dtypes == int

# %%
mi_score = mutual_info_classif(X,y, discrete_features=discrete_features)
mi_score = pd.Series(mi_score, name="Mi_Score", index = X.columns)
mi_score.sort_values(ascending=False)
mi_score
# Out:
# NumDots                               6.553700e-02
# SubdomainLevel                        6.392610e-03
# PathLevel                             5.543887e-02
# UrlLength                             5.263855e-02
# NumDash                               1.140136e-01
# NumDashInHostname                     1.502933e-02
# AtSymbol                              2.079892e-04
# TildeSymbol                           5.362924e-03
# NumUnderscore                         1.037366e-02
# NumPercent                            3.790407e-03
# NumQueryComponents                    3.361768e-02
# NumAmpersand                          1.962894e-02
# NumHash                               1.596890e-03
# NumNumericChars                       1.326711e-01
# NoHttps                               2.854909e-03
# RandomString                          3.643235e-03
# IpAddress                             1.207265e-02
# DomainInSubdomains                    5.497419e-03
# DomainInPaths                         7.003483e-03
# HttpsInHostname                       0.000000e+00
# HostnameLength                        2.564249e-02
# PathLength                            6.413269e-02
# QueryLength                           5.818557e-02
# DoubleSlashInPath                     3.101288e-04
# NumSensitiveWords                     4.180522e-02
# EmbeddedBrandName                     1.066208e-02
# PctExtHyperlinks                      4.687487e-01
# PctExtResourceUrls                    2.886893e-01
# ExtFavicon                            2.398229e-03
# InsecureForms                         5.508096e-02
# RelativeFormAction                    3.419686e-03
# ExtFormAction                         5.613946e-03
# AbnormalFormAction                    1.118934e-02
# PctNullSelfRedirectHyperlinks         2.360458e-01
# FrequentDomainNameMismatch            1.254908e-01
# FakeLinkInStatusBar                   1.113537e-04
# RightClickDisabled                    3.024050e-03
# PopUpWindow                           2.919366e-03
# SubmitInfoToEmail                     7.802617e-02
# IframeOrFrame                         2.805496e-02
# MissingTitle                          7.353661e-03
# ImagesOnlyInForm                      6.785265e-07
# SubdomainLevelRT                      4.503644e-03
# UrlLengthRT                           1.513853e-02
# PctExtResourceUrlsRT                  2.831059e-02
# AbnormalExtFormActionR                1.816610e-02
# ExtMetaScriptLinkRT                   1.175434e-01
# PctExtNullSelfRedirectHyperlinksRT    2.123850e-01
# Name: Mi_Score, dtype: float64

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending = True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width,scores)
    plt.yticks(width, ticks)
    plt.title("MI Scores")

plt.figure(dpi=100, figsize=(12,12))
plot_mi_scores(mi_score)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score,recall_score,f1_score

# %%
def train_logistic(data, top_n):
    top_n_features = mi_score.sort_values(ascending=False).head(top_n).index.tolist()
    X= data[top_n_features]
    y = data['labels']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, shuffle=True)
    lr = LogisticRegression()
    lr.fit(X_train, y_train)
    y_pred = lr.predict(X_test)
    
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test,y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    return precision,recall, f1, accuracy

# %%
arr = []
for i in range(20,51):
    precision,recall,f1, accuracy = train_logistic(df, i)
    print("Performance for Logistic Model with top {} features is precision : {}, recall : {}, accuracy : {}".format(i, precision, recall, f1, accuracy))
    arr.append([i, precision,recall, f1, accuracy])
# Out:
# Performance for Logistic Model with top 20 features is precision : 0.8793774319066148, recall : 0.9243353783231084, accuracy : 0.901296111665005
# Performance for Logistic Model with top 21 features is precision : 0.9084778420038536, recall : 0.9318181818181818, accuracy : 0.92
# Performance for Logistic Model with top 22 features is precision : 0.9115384615384615, recall : 0.9386138613861386, accuracy : 0.9248780487804878
# Performance for Logistic Model with top 23 features is precision : 0.9060987415295256, recall : 0.9464105156723963, accuracy : 0.9258160237388724
# Performance for Logistic Model with top 24 features is precision : 0.923679060665362, recall : 0.9245837414299706, accuracy : 0.9241311796377876
# Performance for Logistic Model with top 25 features is precision : 0.9071090047393365, recall : 0.9400785854616895, accuracy : 0.9232995658465991
# Performance for Logistic Model with top 26 features is precision : 0.9325396825396826, recall : 0.9362549800796812, accuracy : 0.9343936381709742
# Performance for Logistic Model with top 27 features is precision : 0.9274952919020716, recall : 0.9507722007722008, accuracy : 0.9389895138226882
# Performance for Logistic Model with top 28 features is precision : 0.9056429232192414, recall : 0.9477250726040658, accuracy : 0.9262062440870388
# Performance for Logistic Model with top 29 features is precision : 0.912573673870334, recall : 0.9402834008097166, accuracy : 0.9262213359920239
# Performance for Logistic Model with top 30 features is precision : 0.9101123595505618, recall : 0.9455252918287937, accuracy : 0.9274809160305344
# Performance for Logistic Model with top 31 features is precision : 0.9075875486381323, recall : 0.9462474645030426, accuracy : 0.9265143992055611
# Performance for Logistic Model with top 32 features is precision : 0.9143135345666992, recall : 0.9306243805748265, accuracy : 0.9223968565815324
# Performance for Logistic Model with top 33 features is precision : 0.9350253807106599, recall : 0.921, accuracy : 0.9279596977329975
# Performance for Logistic Model with top 34 features is precision : 0.9252704031465093, recall : 0.9344587884806356, accuracy : 0.9298418972332015
# Performance for Logistic Model with top 35 features is precision : 0.9185043144774688, recall : 0.9475766567754699, accuracy : 0.9328140214216164
# Performance for Logistic Model with top 36 features is precision : 0.9262536873156342, recall : 0.942, accuracy : 0.9340604858701042
# Performance for Logistic Model with top 37 features is precision : 0.9139676113360324, recall : 0.9271047227926078, accuracy : 0.9204892966360856
# Performance for Logistic Model with top 38 features is precision : 0.9223205506391348, recall : 0.9417670682730924, accuracy : 0.9319423745653254
# Performance for Logistic Model with top 39 features is precision : 0.908, recall : 0.9190283400809717, accuracy : 0.9134808853118712
# Performance for Logistic Model with top 40 features is precision : 0.9273797841020608, recall : 0.942173479561316, accuracy : 0.9347181008902077
# Performance for Logistic Model with top 41 features is precision : 0.9287109375, recall : 0.9406528189910979, accuracy : 0.9346437346437346
# Performance for Logistic Model with top 42 features is precision : 0.92578125, recall : 0.930323846908734, accuracy : 0.9280469897209985
# Performance for Logistic Model with top 43 features is precision : 0.9294117647058824, recall : 0.948, accuracy : 0.9386138613861386
# Performance for Logistic Model with top 44 features is precision : 0.9231527093596059, recall : 0.9379379379379379, accuracy : 0.9304865938430983
# Performance for Logistic Model with top 45 features is precision : 0.895405669599218, recall : 0.9318413021363174, accuracy : 0.9132602193419741
# Performance for Logistic Model with top 46 features is precision : 0.9345703125, recall : 0.9382352941176471, accuracy : 0.9363992172211351
# Performance for Logistic Model with top 47 features is precision : 0.9210266535044422, recall : 0.9462474645030426, accuracy : 0.9334667333666833
# Performance for Logistic Model with top 48 features is precision : 0.9182452642073778, recall : 0.94655704008222, accuracy : 0.9321862348178138
# Performance for Logistic Model with top 49 features is precision : 0.9279454722492697, recall : 0.9473161033797217, accuracy : 0.9375307427447123
# Performance for Logistic Model with top 50 features is precision : 0.9229229229229229, recall : 0.9379450661241099, accuracy : 0.9303733602421796

# %%
df_log = pd.DataFrame(arr, columns= ['Number of feature', 'precisions', 'recall', 'f1-score', 'accuracy'])
df_log
# Out:
#     Number of feature  precisions    recall  f1-score  accuracy
# 0                  20    0.879377  0.924335  0.901296    0.9010
# 1                  21    0.908478  0.931818  0.920000    0.9180
# 2                  22    0.911538  0.938614  0.924878    0.9230
# 3                  23    0.906099  0.946411  0.925816    0.9250
# 4                  24    0.923679  0.924584  0.924131    0.9225
# 5                  25    0.907109  0.940079  0.923300    0.9205
# 6                  26    0.932540  0.936255  0.934394    0.9340
# 7                  27    0.927495  0.950772  0.938990    0.9360
# 8                  28    0.905643  0.947725  0.926206    0.9220
# 9                  29    0.912574  0.940283  0.926221    0.9260
# 10                 30    0.910112  0.945525  0.927481    0.9240
# 11                 31    0.907588  0.946247  0.926514    0.9260
# 12                 32    0.914314  0.930624  0.922397    0.9210
# 13                 33    0.935025  0.921000  0.927960    0.9285
# 14                 34    0.925270  0.934459  0.929842    0.9290
# 15                 35    0.918504  0.947577  0.932814    0.9310
# 16                 36    0.926254  0.942000  0.934060    0.9335
# 17                 37    0.913968  0.927105  0.920489    0.9220
# 18                 38    0.922321  0.941767  0.931942    0.9315
# 19                 39    0.908000  0.919028  0.913481    0.9140
# 20                 40    0.927380  0.942173  0.934718    0.9340
# 21                 41    0.928711  0.940653  0.934644    0.9335
# 22                 42    0.925781  0.930324  0.928047    0.9265
# 23                 43    0.929412  0.948000  0.938614    0.9380
# 24                 44    0.923153  0.937938  0.930487    0.9300
# 25                 45    0.895406  0.931841  0.913260    0.9130
# 26                 46    0.934570  0.938235  0.936399    0.9350
# 27                 47    0.921027  0.946247  0.933467    0.9335
# 28                 48    0.918245  0.946557  0.932186    0.9330
# 29                 49    0.927945  0.947316  0.937531    0.9365
# 30                 50    0.922923  0.937945  0.930373    0.9310

# %%
sns.lineplot(x = 'Number of feature' , y = 'precisions', data = df_log, label = 'Precision Score')
sns.lineplot(x = 'Number of feature' , y = 'recall', data = df_log, label = 'Recall Score')
sns.lineplot(x = 'Number of feature' , y = 'f1-score', data = df_log, label = 'f1 Score')
sns.lineplot(x = 'Number of feature' , y = 'accuracy', data = df_log, label = 'accuracy Score')
# Out:
# <Axes: xlabel='Number of feature', ylabel='precisions'>

# %%
def train_rfc(data, top_n):
    top_n_features = mi_score.sort_values(ascending=False).head(top_n).index.tolist()
    X= data[top_n_features]
    y = data['labels']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, shuffle=True)
    rfc = RandomForestClassifier(n_estimators=500,
                                criterion='entropy',
                                max_depth=32,
                                max_features=1.0)
    rfc.fit(X_train, y_train)
    y_pred = rfc.predict(X_test)
    
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test,y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    return precision,recall, f1, accuracy

# %%
arr1 = []
for i in range(20,51):
    precision,recall,f1, accuracy = train_rfc(df, i)
    print("Performance for RandomForestClassifier with top {} features is precision : {}, recall : {}, accuracy : {}".format(i, precision, recall, f1, accuracy))
    arr1.append([i, precision,recall, f1, accuracy])
# Out:
# Performance for RandomForestClassifier with top 20 features is precision : 0.9714003944773175, recall : 0.9810756972111554, accuracy : 0.9762140733399405
# Performance for RandomForestClassifier with top 21 features is precision : 0.9850597609561753, recall : 0.9792079207920792, accuracy : 0.9821251241310824
# Performance for RandomForestClassifier with top 22 features is precision : 0.9717073170731707, recall : 0.983218163869694, accuracy : 0.9774288518155054
# Performance for RandomForestClassifier with top 23 features is precision : 0.9773844641101278, recall : 0.9851337958374629, accuracy : 0.981243830207305
# Performance for RandomForestClassifier with top 24 features is precision : 0.9779559118236473, recall : 0.9878542510121457, accuracy : 0.9828801611278952
# Performance for RandomForestClassifier with top 25 features is precision : 0.9841269841269841, recall : 0.9812067260138477, accuracy : 0.9826646854878652
# Performance for RandomForestClassifier with top 26 features is precision : 0.9823008849557522, recall : 0.9784524975514202, accuracy : 0.9803729146221786
# Performance for RandomForestClassifier with top 27 features is precision : 0.9774730656219393, recall : 0.9727095516569201, accuracy : 0.975085490962384
# Performance for RandomForestClassifier with top 28 features is precision : 0.9742574257425742, recall : 0.9723320158102767, accuracy : 0.973293768545994
# Performance for RandomForestClassifier with top 29 features is precision : 0.9745158002038736, recall : 0.9795081967213115, accuracy : 0.977005620848237
# Performance for RandomForestClassifier with top 30 features is precision : 0.9745676500508647, recall : 0.9785495403472931, accuracy : 0.9765545361875637
# Performance for RandomForestClassifier with top 31 features is precision : 0.975485188968335, recall : 0.977482088024565, accuracy : 0.976482617586912
# Performance for RandomForestClassifier with top 32 features is precision : 0.9729448491155047, recall : 0.975991649269311, accuracy : 0.9744658676393955
# Performance for RandomForestClassifier with top 33 features is precision : 0.9712643678160919, recall : 0.9759384023099134, accuracy : 0.9735957753240518
# Performance for RandomForestClassifier with top 34 features is precision : 0.976530612244898, recall : 0.9735503560528993, accuracy : 0.9750382068262863
# Performance for RandomForestClassifier with top 35 features is precision : 0.9812623274161736, recall : 0.969785575048733, accuracy : 0.9754901960784313
# Performance for RandomForestClassifier with top 36 features is precision : 0.9819639278557114, recall : 0.98, accuracy : 0.980980980980981
# Performance for RandomForestClassifier with top 37 features is precision : 0.978, recall : 0.978, accuracy : 0.978
# Performance for RandomForestClassifier with top 38 features is precision : 0.9762140733399405, recall : 0.9830339321357285, accuracy : 0.9796121332670313
# Performance for RandomForestClassifier with top 39 features is precision : 0.984725050916497, recall : 0.9718592964824121, accuracy : 0.9782498735457764
# Performance for RandomForestClassifier with top 40 features is precision : 0.9785932721712538, recall : 0.9836065573770492, accuracy : 0.9810935104752172
# Performance for RandomForestClassifier with top 41 features is precision : 0.981404958677686, recall : 0.9875259875259875, accuracy : 0.9844559585492227
# Performance for RandomForestClassifier with top 42 features is precision : 0.9795121951219512, recall : 0.98046875, accuracy : 0.9799902391410444
# Performance for RandomForestClassifier with top 43 features is precision : 0.9830508474576272, recall : 0.985014985014985, accuracy : 0.9840319361277445
# Performance for RandomForestClassifier with top 44 features is precision : 0.9785056294779939, recall : 0.9755102040816327, accuracy : 0.977005620848237
# Performance for RandomForestClassifier with top 45 features is precision : 0.9797979797979798, recall : 0.9797979797979798, accuracy : 0.9797979797979798
# Performance for RandomForestClassifier with top 46 features is precision : 0.9756345177664975, recall : 0.9826175869120655, accuracy : 0.9791136016301579
# Performance for RandomForestClassifier with top 47 features is precision : 0.9712301587301587, recall : 0.9819458375125376, accuracy : 0.9765586034912718
# Performance for RandomForestClassifier with top 48 features is precision : 0.9782178217821782, recall : 0.9840637450199203, accuracy : 0.9811320754716981
# Performance for RandomForestClassifier with top 49 features is precision : 0.9881070366699702, recall : 0.9764936336924583, accuracy : 0.9822660098522168
# Performance for RandomForestClassifier with top 50 features is precision : 0.9881305637982196, recall : 0.9794117647058823, accuracy : 0.983751846381093

# %%
df_rfc = pd.DataFrame(arr1, columns= ['Number of feature', 'precisions', 'recall', 'f1-score', 'accuracy'])
df_rfc
# Out:
#     Number of feature  precisions    recall  f1-score  accuracy
# 0                  20    0.971400  0.981076  0.976214    0.9760
# 1                  21    0.985060  0.979208  0.982125    0.9820
# 2                  22    0.971707  0.983218  0.977429    0.9770
# 3                  23    0.977384  0.985134  0.981244    0.9810
# 4                  24    0.977956  0.987854  0.982880    0.9830
# 5                  25    0.984127  0.981207  0.982665    0.9825
# 6                  26    0.982301  0.978452  0.980373    0.9800
# 7                  27    0.977473  0.972710  0.975085    0.9745
# 8                  28    0.974257  0.972332  0.973294    0.9730
# 9                  29    0.974516  0.979508  0.977006    0.9775
# 10                 30    0.974568  0.978550  0.976555    0.9770
# 11                 31    0.975485  0.977482  0.976483    0.9770
# 12                 32    0.972945  0.975992  0.974466    0.9755
# 13                 33    0.971264  0.975938  0.973596    0.9725
# 14                 34    0.976531  0.973550  0.975038    0.9755
# 15                 35    0.981262  0.969786  0.975490    0.9750
# 16                 36    0.981964  0.980000  0.980981    0.9810
# 17                 37    0.978000  0.978000  0.978000    0.9780
# 18                 38    0.976214  0.983034  0.979612    0.9795
# 19                 39    0.984725  0.971859  0.978250    0.9785
# 20                 40    0.978593  0.983607  0.981094    0.9815
# 21                 41    0.981405  0.987526  0.984456    0.9850
# 22                 42    0.979512  0.980469  0.979990    0.9795
# 23                 43    0.983051  0.985015  0.984032    0.9840
# 24                 44    0.978506  0.975510  0.977006    0.9775
# 25                 45    0.979798  0.979798  0.979798    0.9800
# 26                 46    0.975635  0.982618  0.979114    0.9795
# 27                 47    0.971230  0.981946  0.976559    0.9765
# 28                 48    0.978218  0.984064  0.981132    0.9810
# 29                 49    0.988107  0.976494  0.982266    0.9820
# 30                 50    0.988131  0.979412  0.983752    0.9835

# %%
sns.lineplot(x = 'Number of feature' , y = 'precisions', data = df_rfc, label = 'Precision Score')
sns.lineplot(x = 'Number of feature' , y = 'recall', data = df_rfc, label = 'Recall Score')
sns.lineplot(x = 'Number of feature' , y = 'f1-score', data = df_rfc, label = 'f1 Score')
sns.lineplot(x = 'Number of feature' , y = 'accuracy', data = df_rfc, label = 'accuracy Score')
# Out:
# <Axes: xlabel='Number of feature', ylabel='precisions'>

# %%
top_n_features = mi_score.sort_values(ascending=False).head(38).index.tolist()
X= df[top_n_features]
y = df['labels']
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, shuffle=True)
rfc = RandomForestClassifier(n_estimators=500,
                criterion='entropy',
                max_depth=32,
                max_features=1.0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
 
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test,y_pred)
accuracy = accuracy_score(y_test, y_pred)

# %%
print("Performance for RFC Model with Top {} features is precision : {}, recall : {}, f1 score : {}, accuracy : {}".format(38, precision, recall, f1, accuracy))
# Out:
# Performance for RFC Model with Top 38 features is precision : 0.9768378650553877, recall : 0.9837728194726166, f1 score : 0.9802930773117736, accuracy : 0.9805

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1014
#            1       0.98      0.98      0.98       986
#
#     accuracy                           0.98      2000
#    macro avg       0.98      0.98      0.98      2000
# weighted avg       0.98      0.98      0.98      2000
#
# [[991  23]
#  [ 16 970]]
